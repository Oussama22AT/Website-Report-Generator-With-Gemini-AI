# %% [markdown]
# # Website Report Generator with Gemini AI
#
# An intelligent tool that automatically generates professional company reports by scraping websites and using AI to identify relevant content.
#
# ## What This Does
#
# This notebook:
# 1. Scrapes website content using BeautifulSoup
# 2. Uses Gemini AI to intelligently select relevant pages
# 3. Aggregates content from multiple pages
# 4. Generates professional reports automatically
# 5. Supports streaming output for real-time display
#
# **Model:** Gemini Flash (free tier compatible)

# %% [markdown]
# ## Setup and Imports
#
# Install required packages:
# ```bash
# pip install python-dotenv requests beautifulsoup4 google-generativeai
# ```

# %%
# imports
# If these fail, please check you're running from an 'activated' environment

import os                # Environment variables access
import requests          # HTTP requests for web scraping
import json              # JSON parsing and formatting
from typing import List  # Type hints
from dotenv import load_dotenv  # Load API keys from .env file
from bs4 import BeautifulSoup   # HTML parsing and content extraction
from IPython.display import Markdown, display, update_display  # Notebook display utilities
import google.generativeai as genai  # Google Gemini AI

# %% [markdown]
# ## Model Configuration
#
# Using Gemini Flash (free tier compatible). The notebook will automatically fall back to alternative models if needed.

# %%
# Auto-fix: Use free tier compatible models
import os
MODEL = 'gemini-flash-latest'  # Free tier compatible model
print(f"Note: Using free tier model: {MODEL}")
# Out:
# Note: Using free tier model: gemini-flash-latest

# %% [markdown]
# ## Website Scraper Class
#
# The `Website` class scrapes a webpage and extracts:
# - Page title
# - Clean text content (removes scripts, styles, images)
# - All links found on the page

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('GEMINI_API_KEY')  
if api_key and len(api_key) > 10:
    print("API key looks good so far")
    genai.configure(api_key=api_key)
else:
    print("There might be a problem with your API key? Please check your GEMINI_API_KEY environment variable!")
    
# Try different model names
MODEL = 'gemini-2.0-flash'  
try:
    model = genai.GenerativeModel(MODEL)
    print(f"Using model: {MODEL}")
except Exception as e:
    print(f"Error with {MODEL}: {e}")
    # Try alternative model
    MODEL = 'gemini-2.0-flash'
    model = genai.GenerativeModel(MODEL)
    print(f"Using fallback model: {MODEL}")
# Out:
# API key looks good so far
# Using model: gemini-2.0-flash

# %% [markdown]
# ## Test the Scraper
#
# Let's test the scraper on a sample website to see what links we can extract.

# %%
# A class to represent a Webpage


headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %% [markdown]
# ## Link Selection Prompt
#
# This prompt tells Gemini how to identify which links are relevant for a company report (About pages, Careers, etc.).

# %%
atmos = Website("https://atmostech.ma")
atmos.links
# Out:
# ['https://atmostech.ma/contact',
#  'https://atmostech.ma/index.php?route=account/account',
#  'https://atmostech.ma/register',
#  'https://atmostech.ma/login',
#  'https://atmostech.ma/index.php?route=account/wishlist',
#  'https://atmostech.ma/cart',
#  'https://atmostech.ma/index.php?route=checkout/checkout',
#  'https://atmostech.ma/',
#  'https://atmostech.ma/cartes-developpement',
#  'https://atmostech.ma/cartes-developpement/arduino',
#  'https://atmostech.ma/cartes-developpement/attiny',
#  'https://atmostech.ma/cartes-developpement/esp',
#  'https://atmostech.ma/cartes-developpement/fpga',
#  'https://atmostech.ma/cartes-developpement/raspberry-maroc',
#  'https://atmostech.ma/cartes-developpement/STM',
#  'https://atmostech.ma/cartes-developpement',
#  'https://atmostech.ma/kit-atmostech',
#  'https://atmostech.ma/kit-atmostech/kit-capteur',
#  'https://atmostech.ma/kit-atmostech/kit-developpement',
#  'https://atmostech.ma/kit-atmostech/kit-raspberry',
#  'https://atmostech.ma/kit-atmostech/kit-robot',
#  'https://atmostech.ma/kit-atmostech',
#  'https://atmostech.ma/modules-capteurs-shields',
#  'https://atmostech.ma/CNC-Impression-3D-maroc',
#  'https://atmostech.ma/composants-circuits-integrés',
#  'https://atmostech.ma/robotique-outils',
#  'https://atmostech.ma/robotique-outils/materiel-prototypage',
#  'https://atmostech.ma/robotique-outils/materiel-soudage',
#  'https://atmostech.ma/robotique-outils/moteurs-drivers',
#  'https://atmostech.ma/robotique-outils/robotiques',
#  'https://atmostech.ma/robotique-outils',
#  'https://atmostech.ma/connecteurs-adaptateurs',
#  'https://atmostech.ma/opto-electronique',
#  'https://atmostech.ma/opto-electronique/afficheurs',
#  'https://atmostech.ma/opto-electronique/LED',
#  'https://atmostech.ma/opto-electronique',
#  'https://atmostech.ma/outillage-accessoires',
#  'https://atmostech.ma/outillage-accessoires/audio-sonorisation',
#  'https://atmostech.ma/outillage-accessoires/bouttons-commutateurs',
#  'https://atmostech.ma/outillage-accessoires/cables',
#  'https://atmostech.ma/outillage-accessoires',
#  'https://atmostech.ma/appareils-de-mesures',
#  'https://atmostech.ma/index.php?route=product/category&path=83',
#  'https://atmostech.ma/index.php?route=product/category&path=99',
#  'https://atmostech.ma/cartes-developpement',
#  'https://atmostech.ma/index.php?route=product/category&path=82',
#  'https://atmostech.ma/kit-atmostech',
#  'https://atmostech.ma/index.php?route=product/category&path=80',
#  'https://atmostech.ma/modules-capteurs-shields',
#  'https://atmostech.ma/index.php?route=product/category&path=81',
#  'https://atmostech.ma/index.php?route=product/category&path=103',
#  'https://atmostech.ma/CNC-Impression-3D-maroc',
#  'https://atmostech.ma/composants-circuits-integrés',
#  'https://atmostech.ma/robotique-outils',
#  'https://atmostech.ma/index.php?route=product/category&path=70',
#  'https://atmostech.ma/connecteurs-adaptateurs',
#  'https://atmostech.ma/opto-electronique',
#  'https://atmostech.ma/outillage-accessoires',
#  'https://atmostech.ma/appareils-de-mesures',
#  'https://atmostech.ma/LED-VERT-5mm',
#  'https://atmostech.ma/LED-VERT-5mm',
#  'https://atmostech.ma/RÉSISTANCE-3-KOHM-1-4W-1-Maroc',
#  'https://atmostech.ma/RÉSISTANCE-3-KOHM-1-4W-1-Maroc',
#  'https://atmostech.ma/RÉSISTANCE-1-KOHM-1-4W-Maroc',
#  'https://atmostech.ma/RÉSISTANCE-1-KOHM-1-4W-Maroc',
#  'https://atmostech.ma/LED-VERT-10mm',
#  'https://atmostech.ma/LED-VERT-10mm',
#  'https://atmostech.ma/LED-Rouge-10mm',
#  'https://atmostech.ma/LED-Rouge-10mm',
#  'https://atmostech.ma/LED-JAUNE-5mm',
#  'https://atmostech.ma/LED-JAUNE-5mm',
#  'https://atmostech.ma/RÉSISTANCE-220-OHM-1-4W-1-Maroc',
#  'https://atmostech.ma/RÉSISTANCE-220-OHM-1-4W-1-Maroc',
#  'https://atmostech.ma/Button-clock-kfc-12-12-7.5H',
#  'https://atmostech.ma/Button-clock-kfc-12-12-7.5H',
#  'https://atmostech.ma/LED-ROUGE-5mm',
#  'https://atmostech.ma/LED-ROUGE-5mm',
#  'https://atmostech.ma/JST-3-PIN',
#  'https://atmostech.ma/JST-3-PIN',
#  'https://atmostech.ma/RÉSISTANCE-200-OHM-1-4W-1-Maroc',
#  'https://atmostech.ma/RÉSISTANCE-200-OHM-1-4W-1-Maroc',
#  'https://atmostech.ma/ARDUINO-UNO-R3-avec-cable',
#  'https://atmostech.ma/ARDUINO-UNO-R3-avec-cable',
#  'https://atmostech.ma/arduino-nano-mq',
#  'https://atmostech.ma/arduino-nano-mq',
#  'https://atmostech.ma/Mega-2560-(ch340)-avec-cable-USB',
#  'https://atmostech.ma/Mega-2560-(ch340)-avec-cable-USB',
#  'https://atmostech.ma/Raspberry-pi-4 model-B-2gb-ram',
#  'https://atmostech.ma/Raspberry-pi-4 model-B-2gb-ram',
#  'https://atmostech.ma/LCD-1602-i2C',
#  'https://atmostech.ma/LCD-1602-i2C',
#  'https://atmostech.ma/breadboard-400p',
#  'https://atmostech.ma/breadboard-400p',
#  'https://atmostech.ma/CNC-Shield-V4-POUR-NANO',
#  'https://atmostech.ma/CNC-Shield-V4-POUR-NANO',
#  'https://atmostech.ma/index.php?route=product/product&product_id=2270',
#  'https://atmostech.ma/index.php?route=product/product&product_id=2270',
#  'https://atmostech.ma/Leonardo-R3-with-Logo',
#  'https://atmostech.ma/Leonardo-R3-with-Logo',
#  'https://atmostech.ma/LED-5mm-TRANSPARENT-Rouge',
#  'https://atmostech.ma/LED-5mm-TRANSPARENT-Rouge',
#  'https://atmostech.ma/L298N-Motor-Driver-Board-Red',
#  'https://atmostech.ma/L298N-Motor-Driver-Board-Red',
#  'https://atmostech.ma/ABS-3D-Filament-1.75mm–1.0 KG-Black',
#  'https://atmostech.ma/ABS-3D-Filament-1.75mm–1.0 KG-Black',
#  'https://atmostech.ma/ZY-201-830-Points-Soldless-Breadboard',
#  'https://atmostech.ma/ZY-201-830-Points-Soldless-Breadboard',
#  'https://atmostech.ma/ECG-Electrode',
#  'https://atmostech.ma/ECG-Electrode',
#  'https://atmostech.ma/index.php?route=product/product&product_id=2711',
#  'https://atmostech.ma/index.php?route=product/product&product_id=2711',
#  'https://atmostech.ma/TB6560-3A-Driver-Board-CNC-Router-Single-Axis-Controller-Stepper-Motor-Drivers',
#  'https://atmostech.ma/TB6560-3A-Driver-Board-CNC-Router-Single-Axis-Controller-Stepper-Motor-Drivers',
#  'https://atmostech.ma/T-GPIO-RASPBERRY',
#  'https://atmostech.ma/T-GPIO-RASPBERRY',
#  'https://atmostech.ma/ULN2003',
#  'https://atmostech.ma/ULN2003',
#  'https://atmostech.ma/IN34-Germanium-Diode',
#  'https://atmostech.ma/IN34-Germanium-Diode',
#  "https://atmostech.ma/Module-d'affichage-OLED-4pin-128x64-couleur-bleue-de-1,3-pouces",
#  "https://atmostech.ma/Module-d'affichage-OLED-4pin-128x64-couleur-bleue-de-1,3-pouces",
#  'https://atmostech.ma/PAM8403-MINI-5V',
#  'https://atmostech.ma/PAM8403-MINI-5V',
#  'https://atmostech.ma/index.php?route=product/product&product_id=2235',
#  'https://atmostech.ma/index.php?route=product/product&product_id=2235',
#  'https://atmostech.ma/SD-Card-Module',
#  'https://atmostech.ma/SD-Card-Module',
#  'https://atmostech.ma/index.php?route=product/product&product_id=2239',
#  'https://atmostech.ma/index.php?route=product/product&product_id=2239',
#  'https://atmostech.ma/Fasizi-LCR-T4-ESR-Meter',
#  'https://atmostech.ma/Fasizi-LCR-T4-ESR-Meter',
#  'https://atmostech.ma/index.php?route=product/product&product_id=2059',
#  'https://atmostech.ma/index.php?route=product/product&product_id=2059',
#  'https://atmostech.ma/index.php?route=product/product&product_id=2055',
#  'https://atmostech.ma/index.php?route=product/product&product_id=2055',
#  'https://atmostech.ma/Jack-femal',
#  'https://atmostech.ma/Jack-femal',
#  'https://atmostech.ma/keyboard-module-4*4-V1.00',
#  'https://atmostech.ma/keyboard-module-4*4-V1.00',
#  'https://atmostech.ma/MaKey-MaKey-Invention-Kit',
#  'https://atmostech.ma/MaKey-MaKey-Invention-Kit',
#  'https://atmostech.ma/W420-Steel-Omni-Ball',
#  'https://atmostech.ma/W420-Steel-Omni-Ball',
#  'https://atmostech.ma/XD-58C-MODULE-CAPTEUR-DE-RYTHME-CARDIAQU',
#  'https://atmostech.ma/XD-58C-MODULE-CAPTEUR-DE-RYTHME-CARDIAQU',
#  'https://atmostech.ma/Cable-multimètre-20A',
#  'https://atmostech.ma/Cable-multimètre-20A',
#  'https://atmostech.ma/V2.0-SENSOR-SHIELD-MEGA',
#  'https://atmostech.ma/V2.0-SENSOR-SHIELD-MEGA',
#  'https://atmostech.ma/BME280-5V-MODULE-CAPTEUR-DE-PRESSION-TEMPÉRATURE-HUMIDITÉ',
#  'https://atmostech.ma/BME280-5V-MODULE-CAPTEUR-DE-PRESSION-TEMPÉRATURE-HUMIDITÉ',
#  'https://atmostech.ma/NEO-M8N-0-10',
#  'https://atmostech.ma/NEO-M8N-0-10',
#  'https://atmostech.ma/Raspberry-PI-3B',
#  'https://atmostech.ma/Raspberry-PI-3B',
#  'https://atmostech.ma/Batterie Rechargeable 18650 2600mAH 3.7V',
#  'https://atmostech.ma/Batterie Rechargeable 18650 2600mAH 3.7V',
#  'https://atmostech.ma/Écran-OLED-Interface-I2C-de-0,96-pouces-SSD1306-bleu-à-4-broches',
#  'https://atmostech.ma/Écran-OLED-Interface-I2C-de-0,96-pouces-SSD1306-bleu-à-4-broches',
#  'https://atmostech.ma/ABS-3D-Filament-1.75mm–1.0KG-Blue',
#  'https://atmostech.ma/ABS-3D-Filament-1.75mm–1.0KG-Blue',
#  'https://atmostech.ma/roulement-608ZZ',
#  'https://atmostech.ma/roulement-608ZZ',
#  'https://atmostech.ma/LED-5mm-TRANSPARENT-Blanc',
#  'https://atmostech.ma/LED-5mm-TRANSPARENT-Blanc',
#  'https://atmostech.ma/à-propos-de-nous',
#  'https://atmostech.ma/livraison',
#  'https://atmostech.ma/politique_confid',
#  'https://atmostech.ma/condition-vente',
#  'https://atmostech.ma/contact',
#  'https://atmostech.ma/retour',
#  'https://atmostech.ma/index.php?route=information/sitemap',
#  'https://atmostech.ma/index.php?route=product/manufacturer',
#  'https://atmostech.ma/index.php?route=account/voucher',
#  'https://atmostech.ma/index.php?route=affiliate/login',
#  'https://atmostech.ma/index.php?route=product/special',
#  'https://atmostech.ma/index.php?route=account/account',
#  'https://atmostech.ma/index.php?route=account/order',
#  'https://atmostech.ma/index.php?route=account/wishlist',
#  'https://atmostech.ma/index.php?route=account/newsletter']

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a report about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %% [markdown]
# ## Get Relevant Links Function
#
# This function uses Gemini to intelligently select the most relevant links from a website's page list. It excludes legal pages (TOS, Privacy), user account pages, and focuses on company-relevant content.

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a report about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %% [markdown]
# ## Collect All Page Details
#
# This function scrapes the landing page and all relevant linked pages to gather comprehensive information about the company.

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a report about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %% [markdown]
# ## Report Generation System
#
# This is the main system prompt that guides Gemini in creating company reports. It can be modified to change the tone (professional, humorous, etc.).

# %%
print(get_links_user_prompt(atmos))
# Out:
# Here is the list of links on the website of https://atmostech.ma - please decide which of these are relevant web links for a report about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://atmostech.ma/contact
# https://atmostech.ma/index.php?route=account/account
# https://atmostech.ma/register
# https://atmostech.ma/login
# https://atmostech.ma/index.php?route=account/wishlist
# https://atmostech.ma/cart
# https://atmostech.ma/index.php?route=checkout/checkout
# https://atmostech.ma/
# https://atmostech.ma/cartes-developpement
# https://atmostech.ma/cartes-developpement/arduino
# https://atmostech.ma/cartes-developpement/attiny
# https://atmostech.ma/cartes-developpement/esp
# https://atmostech.ma/cartes-developpement/fpga
# https://atmostech.ma/cartes-developpement/raspberry-maroc
# https://atmostech.ma/cartes-developpement/STM
# https://atmostech.ma/cartes-developpement
# https://atmostech.ma/kit-atmostech
# https://atmostech.ma/kit-atmostech/kit-capteur
# https://atmostech.ma/kit-atmostech/kit-developpement
# https://atmostech.ma/kit-atmostech/kit-raspberry
# https://atmostech.ma/kit-atmostech/kit-robot
# https://atmostech.ma/kit-atmostech
# https://atmostech.ma/modules-capteurs-shields
# https://atmostech.ma/CNC-Impression-3D-maroc
# https://atmostech.ma/composants-circuits-integrés
# https://atmostech.ma/robotique-outils
# https://atmostech.ma/robotique-outils/materiel-prototypage
# https://atmostech.ma/robotique-outils/materiel-soudage
# https://atmostech.ma/robotique-outils/moteurs-drivers
# https://atmostech.ma/robotique-outils/robotiques
# https://atmostech.ma/robotique-outils
# https://atmostech.ma/connecteurs-adaptateurs
# https://atmostech.ma/opto-electronique
# https://atmostech.ma/opto-electronique/afficheurs
# https://atmostech.ma/opto-electronique/LED
# https://atmostech.ma/opto-electronique
# https://atmostech.ma/outillage-accessoires
# https://atmostech.ma/outillage-accessoires/audio-sonorisation
# https://atmostech.ma/outillage-accessoires/bouttons-commutateurs
# https://atmostech.ma/outillage-accessoires/cables
# https://atmostech.ma/outillage-accessoires
# https://atmostech.ma/appareils-de-mesures
# https://atmostech.ma/index.php?route=product/category&path=83
# https://atmostech.ma/index.php?route=product/category&path=99
# https://atmostech.ma/cartes-developpement
# https://atmostech.ma/index.php?route=product/category&path=82
# https://atmostech.ma/kit-atmostech
# https://atmostech.ma/index.php?route=product/category&path=80
# https://atmostech.ma/modules-capteurs-shields
# https://atmostech.ma/index.php?route=product/category&path=81
# https://atmostech.ma/index.php?route=product/category&path=103
# https://atmostech.ma/CNC-Impression-3D-maroc
# https://atmostech.ma/composants-circuits-integrés
# https://atmostech.ma/robotique-outils
# https://atmostech.ma/index.php?route=product/category&path=70
# https://atmostech.ma/connecteurs-adaptateurs
# https://atmostech.ma/opto-electronique
# https://atmostech.ma/outillage-accessoires
# https://atmostech.ma/appareils-de-mesures
# https://atmostech.ma/LED-VERT-5mm
# https://atmostech.ma/LED-VERT-5mm
# https://atmostech.ma/RÉSISTANCE-3-KOHM-1-4W-1-Maroc
# https://atmostech.ma/RÉSISTANCE-3-KOHM-1-4W-1-Maroc
# https://atmostech.ma/RÉSISTANCE-1-KOHM-1-4W-Maroc
# https://atmostech.ma/RÉSISTANCE-1-KOHM-1-4W-Maroc
# https://atmostech.ma/LED-VERT-10mm
# https://atmostech.ma/LED-VERT-10mm
# https://atmostech.ma/LED-Rouge-10mm
# https://atmostech.ma/LED-Rouge-10mm
# https://atmostech.ma/LED-JAUNE-5mm
# https://atmostech.ma/LED-JAUNE-5mm
# https://atmostech.ma/RÉSISTANCE-220-OHM-1-4W-1-Maroc
# https://atmostech.ma/RÉSISTANCE-220-OHM-1-4W-1-Maroc
# https://atmostech.ma/Button-clock-kfc-12-12-7.5H
# https://atmostech.ma/Button-clock-kfc-12-12-7.5H
# https://atmostech.ma/LED-ROUGE-5mm
# https://atmostech.ma/LED-ROUGE-5mm
# https://atmostech.ma/JST-3-PIN
# https://atmostech.ma/JST-3-PIN
# https://atmostech.ma/RÉSISTANCE-200-OHM-1-4W-1-Maroc
# https://atmostech.ma/RÉSISTANCE-200-OHM-1-4W-1-Maroc
# https://atmostech.ma/ARDUINO-UNO-R3-avec-cable
# https://atmostech.ma/ARDUINO-UNO-R3-avec-cable
# https://atmostech.ma/arduino-nano-mq
# https://atmostech.ma/arduino-nano-mq
# https://atmostech.ma/Mega-2560-(ch340)-avec-cable-USB
# https://atmostech.ma/Mega-2560-(ch340)-avec-cable-USB
# https://atmostech.ma/Raspberry-pi-4 model-B-2gb-ram
# https://atmostech.ma/Raspberry-pi-4 model-B-2gb-ram
# https://atmostech.ma/LCD-1602-i2C
# https://atmostech.ma/LCD-1602-i2C
# https://atmostech.ma/breadboard-400p
# https://atmostech.ma/breadboard-400p
# https://atmostech.ma/CNC-Shield-V4-POUR-NANO
# https://atmostech.ma/CNC-Shield-V4-POUR-NANO
# https://atmostech.ma/index.php?route=product/product&product_id=2270
# https://atmostech.ma/index.php?route=product/product&product_id=2270
# https://atmostech.ma/Leonardo-R3-with-Logo
# https://atmostech.ma/Leonardo-R3-with-Logo
# https://atmostech.ma/LED-5mm-TRANSPARENT-Rouge
# https://atmostech.ma/LED-5mm-TRANSPARENT-Rouge
# https://atmostech.ma/L298N-Motor-Driver-Board-Red
# https://atmostech.ma/L298N-Motor-Driver-Board-Red
# https://atmostech.ma/ABS-3D-Filament-1.75mm–1.0 KG-Black
# https://atmostech.ma/ABS-3D-Filament-1.75mm–1.0 KG-Black
# https://atmostech.ma/ZY-201-830-Points-Soldless-Breadboard
# https://atmostech.ma/ZY-201-830-Points-Soldless-Breadboard
# https://atmostech.ma/ECG-Electrode
# https://atmostech.ma/ECG-Electrode
# https://atmostech.ma/index.php?route=product/product&product_id=2711
# https://atmostech.ma/index.php?route=product/product&product_id=2711
# https://atmostech.ma/TB6560-3A-Driver-Board-CNC-Router-Single-Axis-Controller-Stepper-Motor-Drivers
# https://atmostech.ma/TB6560-3A-Driver-Board-CNC-Router-Single-Axis-Controller-Stepper-Motor-Drivers
# https://atmostech.ma/T-GPIO-RASPBERRY
# https://atmostech.ma/T-GPIO-RASPBERRY
# https://atmostech.ma/ULN2003
# https://atmostech.ma/ULN2003
# https://atmostech.ma/IN34-Germanium-Diode
# https://atmostech.ma/IN34-Germanium-Diode
# https://atmostech.ma/Module-d'affichage-OLED-4pin-128x64-couleur-bleue-de-1,3-pouces
# https://atmostech.ma/Module-d'affichage-OLED-4pin-128x64-couleur-bleue-de-1,3-pouces
# https://atmostech.ma/PAM8403-MINI-5V
# https://atmostech.ma/PAM8403-MINI-5V
# https://atmostech.ma/index.php?route=product/product&product_id=2235
# https://atmostech.ma/index.php?route=product/product&product_id=2235
# https://atmostech.ma/SD-Card-Module
# https://atmostech.ma/SD-Card-Module
# https://atmostech.ma/index.php?route=product/product&product_id=2239
# https://atmostech.ma/index.php?route=product/product&product_id=2239
# https://atmostech.ma/Fasizi-LCR-T4-ESR-Meter
# https://atmostech.ma/Fasizi-LCR-T4-ESR-Meter
# https://atmostech.ma/index.php?route=product/product&product_id=2059
# https://atmostech.ma/index.php?route=product/product&product_id=2059
# https://atmostech.ma/index.php?route=product/product&product_id=2055
# https://atmostech.ma/index.php?route=product/product&product_id=2055
# https://atmostech.ma/Jack-femal
# https://atmostech.ma/Jack-femal
# https://atmostech.ma/keyboard-module-4*4-V1.00
# https://atmostech.ma/keyboard-module-4*4-V1.00
# https://atmostech.ma/MaKey-MaKey-Invention-Kit
# https://atmostech.ma/MaKey-MaKey-Invention-Kit
# https://atmostech.ma/W420-Steel-Omni-Ball
# https://atmostech.ma/W420-Steel-Omni-Ball
# https://atmostech.ma/XD-58C-MODULE-CAPTEUR-DE-RYTHME-CARDIAQU
# https://atmostech.ma/XD-58C-MODULE-CAPTEUR-DE-RYTHME-CARDIAQU
# https://atmostech.ma/Cable-multimètre-20A
# https://atmostech.ma/Cable-multimètre-20A
# https://atmostech.ma/V2.0-SENSOR-SHIELD-MEGA
# https://atmostech.ma/V2.0-SENSOR-SHIELD-MEGA
# https://atmostech.ma/BME280-5V-MODULE-CAPTEUR-DE-PRESSION-TEMPÉRATURE-HUMIDITÉ
# https://atmostech.ma/BME280-5V-MODULE-CAPTEUR-DE-PRESSION-TEMPÉRATURE-HUMIDITÉ
# https://atmostech.ma/NEO-M8N-0-10
# https://atmostech.ma/NEO-M8N-0-10
# https://atmostech.ma/Raspberry-PI-3B
# https://atmostech.ma/Raspberry-PI-3B
# https://atmostech.ma/Batterie Rechargeable 18650 2600mAH 3.7V
# https://atmostech.ma/Batterie Rechargeable 18650 2600mAH 3.7V
# https://atmostech.ma/Écran-OLED-Interface-I2C-de-0,96-pouces-SSD1306-bleu-à-4-broches
# https://atmostech.ma/Écran-OLED-Interface-I2C-de-0,96-pouces-SSD1306-bleu-à-4-broches
# https://atmostech.ma/ABS-3D-Filament-1.75mm–1.0KG-Blue
# https://atmostech.ma/ABS-3D-Filament-1.75mm–1.0KG-Blue
# https://atmostech.ma/roulement-608ZZ
# https://atmostech.ma/roulement-608ZZ
# https://atmostech.ma/LED-5mm-TRANSPARENT-Blanc
# https://atmostech.ma/LED-5mm-TRANSPARENT-Blanc
# https://atmostech.ma/à-propos-de-nous
# https://atmostech.ma/livraison
# https://atmostech.ma/politique_confid
# https://atmostech.ma/condition-vente
# https://atmostech.ma/contact
# https://atmostech.ma/retour
# https://atmostech.ma/index.php?route=information/sitemap
# https://atmostech.ma/index.php?route=product/manufacturer
# https://atmostech.ma/index.php?route=account/voucher
# https://atmostech.ma/index.php?route=affiliate/login
# https://atmostech.ma/index.php?route=product/special
# https://atmostech.ma/index.php?route=account/account
# https://atmostech.ma/index.php?route=account/order
# https://atmostech.ma/index.php?route=account/wishlist
# https://atmostech.ma/index.php?route=account/newsletter

# %% [markdown]
# ## Generate Company Report
#
# This function creates a complete report by:
# 1. Scraping the website for relevant information
# 2. Feeding it to Gemini with instructions to create a report
# 3. Displaying the result as formatted markdown
#
# Try it with your own company website!

# %%
def get_links(url):
    website = Website(url)
    
    # Combine system prompt and user prompt for Gemini
    full_prompt = link_system_prompt + "\n\n" + get_links_user_prompt(website)
    
    # Configure generation for JSON response
    try:
        # Try with response_mime_type for newer models
        generation_config = genai.types.GenerationConfig(
            temperature=0.1,
            response_mime_type="application/json"
        )
        response = model.generate_content(
            full_prompt,
            generation_config=generation_config
        )
    except:
        
        generation_config = genai.types.GenerationConfig(
            temperature=0.1
        )
        full_prompt_with_json = full_prompt + "\n\nRespond ONLY with valid JSON, no other text."
        response = model.generate_content(
            full_prompt_with_json,
            generation_config=generation_config
        )
    
    result = response.text
    return json.loads(result)

# %% [markdown]
# ## Streamed Report Generation
#
# This version streams the report output character by character for a more dynamic display experience.

# %%
get_links("https://www.atmostech.ma/")
# Out:
# {'links': [{'type': 'contact page', 'url': 'https://atmostech.ma/contact'},
#   {'type': 'about us page',
#    'url': 'https://atmostech.ma/%C3%A0-propos-de-nous'}]}

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://atmostech.ma/"))
# Out:
# Found links: {'links': [{'type': 'contact page', 'url': 'https://atmostech.ma/contact'}, {'type': 'homepage', 'url': 'https://atmostech.ma/'}, {'type': 'about page', 'url': 'https://atmostech.ma/%C3%A0-propos-de-nous'}]}
# Landing page:
# Webpage Title:
# Arduino Raspberry-pi & Composants électroniques | Maroc | Atmostech
# Webpage Contents:
# +212674744471 / +212664166235
# Compte
# Inscription
# Connexion
# Liste de souhaits (0)
# Panier
# Commander
# 0 article(s) - 0,00DH
# Votre panier est vide !
# Catégories
# Cartes de développement
# Arduino
# Attiny
# ESP
# FPGA
# Raspberry
# STM
# Show All Cartes de développement
# Kit Atmostech
# Kit Capteur
# Kit De développement
# Kit Raspberry
# Kit Robot
# Show All Kit Atmostech
# Modules , capteurs , Shields
# CNC et Impression-3D
# Composants / Circuits intégrés
# Robotique , Outils
# Matériel de prototypage
# Matériel de soudage
# Moteur , Drivers
# Robotique
# Show All Robotique , Outils
# Connecteurs ,  Adaptateurs
# OPto-Electronique
# Afficheurs
# LED
# Show All OPto-Electronique
# Outillage , Accessoires
# Audio , Sonorisation
# Bouttons , Commutateurs
# Câbles
# Show All Outillage , Accessoires
# Appareils de mesure
# Batteries , Accessoires
# Boitier ABS et Support
# Cartes de développement
# Convertisseur
# Kit Atmostech
# Microcontroleur , Mémoire
# Modules , capteurs , Shields
# Programmateurs
# Résistance
# CNC et Impression-3D
# Composants / Circuits intégrés
# Robotique , Outils
# Capteurs
# Connecteurs ,  Adaptateurs
# OPto-Electronique
# Outillage , Accessoires
# Appareils de mesure
# Meilleures ventes
# LED VERT 5mm
# Une LED verte standard de 5 mm, utilisable à des fins d'indication ou de visualisation. Elle peut êt..
# 1,00DH
# Hors taxe : 1,00DH
# Ajouter au panier
# RÉSISTANCE 3 KOHM 1/4W +/- 1% Maroc
# ..
# 1,00DH
# Hors taxe : 1,00DH
# Ajouter au panier
# RÉSISTANCE 1 KOHM 1/4W +/- 1% Maroc
# ..
# 1,00DH
# Hors taxe : 1,00DH
# Ajouter au panier
# LED VERT 10mm
# Caractéristiques:460-470nmtension: 2.9-3.5VDCcourant: 20mAAngle de vue: 40-60 degree800-1000 MCD out..
# 2,00DH
# Hors taxe : 2,00DH
# Ajouter au panier
# LED Rouge 10mm
# Lentille: diamètre 10 mm / rondTension directe: 3V-3.2VCourant: 20mACouleur d’émission: rouge (455-4..
# 2,00DH
# Hors taxe : 2,00DH
# Ajouter au panier
# LED JAUNE 5mm
# Les LED, ces petites puces clignotantes, sont indispensables pour l'indication de l'alimentation, l'..
# 1,00DH
# Hors taxe : 1,00DH
# Ajouter au panier
# RÉSISTANCE 220 OHM 1/4W +/- 1% Maroc
# ..
# 1,00DH
# Hors taxe : 1,00DH
# Ajouter au panier
# Bouton clock kfc-12*12-7.5H
# Matériaux du corpsPlastiqueLongueur x Hauteur x Largeur12 mm x 12 mm x 7.5 mmNombre de terminaux4Ave..
# 2,00DH
# Hors taxe : 2,00DH
# Ajouter au panier
# LED ROUGE 5mm
# Une LED rouge standard  de 5 mm  , utilisable à des fins d'indication ou de visu..
# 1,00DH
# Hors taxe : 1,00DH
# Ajouter au panier
# JST 3 broches femelle
# Connecteurs femelles à broches 2,54 mmEnsemble de connecteurs JST couramment utilisés en robotique e..
# 5,00DH
# Hors taxe : 5,00DH
# Ajouter au panier
# RÉSISTANCE 200 OHM 1/4W +/- 1% Maroc
# ..
# 1,00DH
# Hors taxe : 1,00DH
# Ajouter au panier
# ARDUINO UNO R3   + avec câble
# DescriptionArduino Uno R3Arduino Uno est basée sur le microcontrôleur ATmega328P d’Atmel. Ce microco..
# 120,00DH
# Hors taxe : 120,00DH
# Ajouter au panier
# En vedette
# ARDUINO NANO  + avec câble
# Arduino Nano :Arduino Nano maroc est une carte de développement open-source basée sur un microcontrô..
# 75,00DH
# Hors taxe : 75,00DH
# Ajouter au panier
# Arduino Méga 2560 R3 sans logo + Câble USB
# Arduino Méga 2560 (CH340) + Câble USBLa carte Arduino Méga est dotée d’un microcontrôleur ATMega2560..
# 199,00DH
# Hors taxe : 199,00DH
# Ajouter au panier
# Raspberry pi 4 model B 2gb ram
# 2 Go de mémoire SDRAM LPDDR4-3200 bProcesseur Broadcom
# BCM2711, SoC quadricœur Cortex-A72 (ARM v8) ..
# 950,00DH
# Hors taxe : 950,00DH
# Ajouter au panier
# LCD 1602 i2C Afficheur
# LCD
# 1602 i2C Afficheur LCD 1602 avec I2C s’agit d’une interface I2C,un
# module d’affichage LCD..
# 50,00DH
# Hors taxe : 50,00DH
# Ajouter au panier
# Plaque d'essai 400 Points
# Platine d’essai est particulièrement utile pour les développeurs électroniques et les étudiants en é..
# 19,00DH
# Hors taxe : 19,00DH
# Ajouter au panier
# CNC Shield V4 POUR NANO
# DescriptionShield CNC  et imprimant 3D, v4 pour l’Arduino NanoDescription :Ce module qui se bas..
# 75,00DH
# Hors taxe : 75,00DH
# Ajouter au panier
# Adaptateur Alimentation 12v
# Alimentation Chargeur 12V–2A Cette alimentation électrique est conçue pour alimenter les appare..
# 50,00DH
# Hors taxe : 50,00DH
# Ajouter au panier
# Arduino Leonardo R3 avec logo
# MicrocontrôleurATMega32u4Dimensions70 mm x 53 mm x 15 mmTension de fonctionnement5vtension d'aliment..
# 160,00DH
# Hors taxe : 160,00DH
# Ajouter au panier
# LED 5mm TRANSPARENT Rouge
# DescriptionEnsemble de 10 LEDSDiode LED rouge de très haute qualité avec une longueur d'onde de 620-..
# 1,00DH
# Hors taxe : 1,00DH
# Ajouter au panier
# Carte de commande de moteur L298N rouge
# Un microcontrôleur fonctionnant normalement sous 5 V ou 3,3 V ne peut pas être utilisé directement p..
# 45,00DH
# Hors taxe : 45,00DH
# Ajouter au panier
# Filament ABS 3D 1,75 mm – 1 kg – Noir
# Filament ABS de couleur noire pour imprimantes 3D 1,75 mm, 1,0 kg...
# 270,00DH
# Hors taxe : 270,00DH
# Ajouter au panier
# ZY-201 830 Points Plaque d'essai
# Bornier : point de raccordement 630Bandes de distribution : point de raccordement 200Matériau : plas..
# 76,00DH
# Hors taxe : 76,00DH
# Ajouter au panier
# Électrode ECG
# Feuille d’électrode pour adulte, accessoires de machine à ECG, patch de plomb d’électrocardiographie..
# 15,00DH
# Hors taxe : 15,00DH
# Ajouter au panier
# Rack PCB 40mm
# ..
# 20,00DH
# Hors taxe : 20,00DH
# Ajouter au panier
# Carte de pilote TB6560 3A pour routeur CNC, contrôleur à axe unique, pilotes de moteur pas à pas
# Les moteurs pas à pas  sont utilisés dans des applications nécessitant un contrôle précis ..
# 130,00DH
# Hors taxe : 130,00DH
# Ajouter au panier
# T GPIO RASPBERRY
# Le kit d'extension GPIO permet d'étendre l'interface GPIO du Raspberry Pi B+. Il vous permet de conn..
# 50,00DH
# Hors taxe : 50,00DH
# Ajouter au panier
# ULN2003A Driver Moteur Pas à pas
# Le circuit intégré ULN2003 est l'un des circuits de commande de moteur les plus couramment utilisés...
# 23,00DH
# Hors taxe : 23,00DH
# Ajouter au panier
# IN34 Germanium Diode
# ·
# Courant d'appel direct
# max. (Ifsm) : 500mA
#
# ·&n..
# 2,00DH
# Hors taxe : 2,00DH
# Ajouter au panier
# Écran d'affichage OLED 4pin 128x64 couleur bleue de 1,3 pouces
# Module OLED 1,3 "Module d'affichage 1,3 pouces Blanc 128X64 SPI / IIC I2C Communiquer la couleur Mod..
# 120,00DH
# Hors taxe : 120,00DH
# Ajouter au panier
# PAM8403 MINI 5V
# Les amplificateurs audio sont essentiels à tout système musical. Ils permettent de diffuser le son p..
# 25,00DH
# Hors taxe : 25,00DH
# Ajouter au panier
# QUARTZ
# ..
# 4,00DH
# Hors taxe : 4,00DH
# Ajouter au panier
# Module SD Card
# Alimentation:4.5V – 5.5V, 3.3VTrous: 4 x M2Connection PINS: GND, VCC, MISO, MOSI, SCK, CSSTaille:45 ..
# 20,00DH
# Hors taxe : 20,00DH
# Ajouter au panier
# Connecteur male DB9 à 9 broches YS-MH907A
# ..
# 45,00DH
# Hors taxe : 45,00DH
# Ajouter au panier
# Compteur ESR Fasizi LCR-T4
# Ajouter une fonction de détection de tension de démarrageDétection automatique des transistors NPN e..
# 170,00DH
# Hors taxe : 170,00DH
# Ajouter au panier
# Gaine 127 pcs
# - 30 gaines thermo-rétractables Ø 2,0 mm, longueur 40 mm- 25 gaines thermo-rétractables Ø 2,5 mm, lo..
# 70,00DH
# Hors taxe : 70,00DH
# Ajouter au panier
# Gaine 560 pcs
# Description
#
# Kit de Gaine 560 piéces
# Un Kit de gaines thermorétractable de 12 tailles et..
# 130,00DH
# Hors taxe : 130,00DH
# Ajouter au panier
# Jack femelle
# Nom du produit: Connecteur de montage de carte PCB de prise d'alimentation CC;Type : 5.5mm x 2.1mm S..
# 5,00DH
# Hors taxe : 5,00DH
# Ajouter au panier
# module clavier 4*4 V1.00
# Fonctionnalité:1. 4X4 ARRAY 16 TOUCHES: Le module de commutation du clavier est de conception 4x4 ar..
# 50,00DH
# Hors taxe : 50,00DH
# Ajouter au panier
# Kit d'invention MaKey MaKey
# De la marqueMAKEY MAKEYSi vous pouvez l'imaginer, vous pouvez le réaliser !Page précédenteDU PL..
# 390,00DH
# Hors taxe : 390,00DH
# Ajouter au panier
# Boule omnidirectionnelle en acier W420
# Description:Matériau : acier + plastiqueDirection : roulettes universellesSpécifications : 50 * 25 *..
# 13,00DH
# Hors taxe : 13,00DH
# Ajouter au panier
# XD-58C MODULE CAPTEUR DE RYTHME CARDIAQUE
# CaractéristiqueDescriptionTechnologiePhotopléthysmographie (PPG)Longueur d’onde de la LED940 nmType ..
# 70,00DH
# Hors taxe : 70,00DH
# Ajouter au panier
# Cable  multimètre 20A
# Cette paire de fils de test peut être utilisée avec la plupart des multimètres et constitue une sond..
# 30,00DH
# Hors taxe : 30,00DH
# Ajouter au panier
# V2.0 CAPTEUR SHIELD MEGA
# Module
# LM2596 avec affichage digital 2A
#
# Module abaisseur de tension
# DC/DC à base de régulateur ..
# 65,00DH
# Hors taxe : 65,00DH
# Ajouter au panier
# BMP 280 5V MODULE CAPTEUR DE PRESSION, TEMPÉRATURE, HUMIDITÉ
# MODULE CAPTEUR DE PRESSION, TEMPÉRATURE, HUMIDITÉ HAUTE PRÉCISION BME280 5VGY-BME280 BME280 est un c..
# 60,00DH
# Hors taxe : 60,00DH
# Ajouter au panier
# NEO-M8N-0-10
# L'antenne en céramique fournit un signal très fortAvec voyant LEDLe débit en bauds par défaut est de..
# 350,00DH
# Hors taxe : 350,00DH
# Ajouter au panier
# Raspberry PI 3B+
# Raspberry Pi 3 modèle B+ 2018
# Le Raspberry Pi 3 Model B + est le dernier produit de la gam..
# 850,00DH
# Hors taxe : 850,00DH
# Ajouter au panier
# Batterie Rechargeable 18650 2600mAH 3.7V
# Il s'agit d'une batterie 18650 3C originale de 2600 mAh de Hongli. Elle peut être cha..
# 19,00DH
# Hors taxe : 19,00DH
# Ajouter au panier
# Écran OLED Interface I2C de 0,96 pouces / SSD1306 bleu à 4 broches
# Les écrans OLED sont populaires pour leur faible consommation de courant et leurs angles de vision l..
# 100,00DH
# Hors taxe : 100,00DH
# Ajouter au panier
# Filament ABS 3D 1,75 mm – 1 kg – Bleu
# Filament ABS de couleur bleue pour imprimantes 3D 1,75 mm, 1,0 kg...
# 270,00DH
# Hors taxe : 270,00DH
# Ajouter au panier
# Roulement à billes 608ZZ (8 x 22 x 7 mm)
# Spécifications:
# Type: Roulement à billes à rainure profonde
# Lubrification : Graisse
# Matériau: Aci..
# 9,00DH
# Hors taxe : 9,00DH
# Ajouter au panier
# LED 10mm TRANSPARENTE Blanche
# Diode LED blanche de très haute qualité avec une température de couleur de 6000-9000K. La puissance ..
# 2,00DH
# Hors taxe : 2,00DH
# Ajouter au panier
# Informations
# Qui sommes nous
# Information sur la livraison
# Politique de confidentialité
# Conditions de vente
# Service client
# Nous contacter
# Retour de marchandise
# Plan du site
# Extras
# Fabricants
# Chèques-cadeaux
# Affiliations
# Promotions
# Mon compte
# Mon compte
# Historique de commandes
# Liste de souhaits
# Lettre d’information
# Développé Par
# ZOULO
# - ATMOSTECH © 2025
#
#
#
# contact page
# Webpage Title:
# Nous contacter
# Webpage Contents:
# +212674744471 / +212664166235
# Compte
# Inscription
# Connexion
# Liste de souhaits (0)
# Panier
# Commander
# 0 article(s) - 0,00DH
# Votre panier est vide !
# Catégories
# Cartes de développement
# Arduino
# Attiny
# ESP
# FPGA
# Raspberry
# STM
# Show All Cartes de développement
# Kit Atmostech
# Kit Capteur
# Kit De développement
# Kit Raspberry
# Kit Robot
# Show All Kit Atmostech
# Modules , capteurs , Shields
# CNC et Impression-3D
# Composants / Circuits intégrés
# Robotique , Outils
# Matériel de prototypage
# Matériel de soudage
# Moteur , Drivers
# Robotique
# Show All Robotique , Outils
# Connecteurs ,  Adaptateurs
# OPto-Electronique
# Afficheurs
# LED
# Show All OPto-Electronique
# Outillage , Accessoires
# Audio , Sonorisation
# Bouttons , Commutateurs
# Câbles
# Show All Outillage , Accessoires
# Appareils de mesure
# Nous contacter
# Nous contacter
# Localisation
# ATMOSTECH
# Casablanca
# Voir le plan Google
# Téléphone :
# +212674744471 / +212664166235
# Horaires d’ouverture
# 8 : 00 --- 18 : 00
# Nos boutiques
# ATMOSTECH
# ATMOSTECH
# N° 5, Rue Hassan Elbasri -ex César Franck ,quartier: Belvédère - Casablanca
# Voir le plan Google
# Téléphone :
# +2120674744471
# Horaires d’ouverture
# 8 : 00---18 : 00
# Nous contacter
# Nom
# Adresse courriel
# Demande de renseignements
# Informations
# Qui sommes nous
# Information sur la livraison
# Politique de confidentialité
# Conditions de vente
# Service client
# Nous contacter
# Retour de marchandise
# Plan du site
# Extras
# Fabricants
# Chèques-cadeaux
# Affiliations
# Promotions
# Mon compte
# Mon compte
# Historique de commandes
# Liste de souhaits
# Lettre d’information
# Développé Par
# ZOULO
# - ATMOSTECH © 2025
#
#
#
# homepage
# Webpage Title:
# Arduino Raspberry-pi & Composants électroniques | Maroc | Atmostech
# Webpage Contents:
# +212674744471 / +212664166235
# Compte
# Inscription
# Connexion
# Liste de souhaits (0)
# Panier
# Commander
# 0 article(s) - 0,00DH
# Votre panier est vide !
# Catégories
# Cartes de développement
# Arduino
# Attiny
# ESP
# FPGA
# Raspberry
# STM
# Show All Cartes de développement
# Kit Atmostech
# Kit Capteur
# Kit De développement
# Kit Raspberry
# Kit Robot
# Show All Kit Atmostech
# Modules , capteurs , Shields
# CNC et Impression-3D
# Composants / Circuits intégrés
# Robotique , Outils
# Matériel de prototypage
# Matériel de soudage
# Moteur , Drivers
# Robotique
# Show All Robotique , Outils
# Connecteurs ,  Adaptateurs
# OPto-Electronique
# Afficheurs
# LED
# Show All OPto-Electronique
# Outillage , Accessoires
# Audio , Sonorisation
# Bouttons , Commutateurs
# Câbles
# Show All Outillage , Accessoires
# Appareils de mesure
# Batteries , Accessoires
# Boitier ABS et Support
# Cartes de développement
# Convertisseur
# Kit Atmostech
# Microcontroleur , Mémoire
# Modules , capteurs , Shields
# Programmateurs
# Résistance
# CNC et Impression-3D
# Composants / Circuits intégrés
# Robotique , Outils
# Capteurs
# Connecteurs ,  Adaptateurs
# OPto-Electronique
# Outillage , Accessoires
# Appareils de mesure
# Meilleures ventes
# LED VERT 5mm
# Une LED verte standard de 5 mm, utilisable à des fins d'indication ou de visualisation. Elle peut êt..
# 1,00DH
# Hors taxe : 1,00DH
# Ajouter au panier
# RÉSISTANCE 3 KOHM 1/4W +/- 1% Maroc
# ..
# 1,00DH
# Hors taxe : 1,00DH
# Ajouter au panier
# RÉSISTANCE 1 KOHM 1/4W +/- 1% Maroc
# ..
# 1,00DH
# Hors taxe : 1,00DH
# Ajouter au panier
# LED VERT 10mm
# Caractéristiques:460-470nmtension: 2.9-3.5VDCcourant: 20mAAngle de vue: 40-60 degree800-1000 MCD out..
# 2,00DH
# Hors taxe : 2,00DH
# Ajouter au panier
# LED Rouge 10mm
# Lentille: diamètre 10 mm / rondTension directe: 3V-3.2VCourant: 20mACouleur d’émission: rouge (455-4..
# 2,00DH
# Hors taxe : 2,00DH
# Ajouter au panier
# LED JAUNE 5mm
# Les LED, ces petites puces clignotantes, sont indispensables pour l'indication de l'alimentation, l'..
# 1,00DH
# Hors taxe : 1,00DH
# Ajouter au panier
# RÉSISTANCE 220 OHM 1/4W +/- 1% Maroc
# ..
# 1,00DH
# Hors taxe : 1,00DH
# Ajouter au panier
# Bouton clock kfc-12*12-7.5H
# Matériaux du corpsPlastiqueLongueur x Hauteur x Largeur12 mm x 12 mm x 7.5 mmNombre de terminaux4Ave..
# 2,00DH
# Hors taxe : 2,00DH
# Ajouter au panier
# LED ROUGE 5mm
# Une LED rouge standard  de 5 mm  , utilisable à des fins d'indication ou de visu..
# 1,00DH
# Hors taxe : 1,00DH
# Ajouter au panier
# JST 3 broches femelle
# Connecteurs femelles à broches 2,54 mmEnsemble de connecteurs JST couramment utilisés en robotique e..
# 5,00DH
# Hors taxe : 5,00DH
# Ajouter au panier
# RÉSISTANCE 200 OHM 1/4W +/- 1% Maroc
# ..
# 1,00DH
# Hors taxe : 1,00DH
# Ajouter au panier
# ARDUINO UNO R3   + avec câble
# DescriptionArduino Uno R3Arduino Uno est basée sur le microcontrôleur ATmega328P d’Atmel. Ce microco..
# 120,00DH
# Hors taxe : 120,00DH
# Ajouter au panier
# En vedette
# ARDUINO NANO  + avec câble
# Arduino Nano :Arduino Nano maroc est une carte de développement open-source basée sur un microcontrô..
# 75,00DH
# Hors taxe : 75,00DH
# Ajouter au panier
# Arduino Méga 2560 R3 sans logo + Câble USB
# Arduino Méga 2560 (CH340) + Câble USBLa carte Arduino Méga est dotée d’un microcontrôleur ATMega2560..
# 199,00DH
# Hors taxe : 199,00DH
# Ajouter au panier
# Raspberry pi 4 model B 2gb ram
# 2 Go de mémoire SDRAM LPDDR4-3200 bProcesseur Broadcom
# BCM2711, SoC quadricœur Cortex-A72 (ARM v8) ..
# 950,00DH
# Hors taxe : 950,00DH
# Ajouter au panier
# LCD 1602 i2C Afficheur
# LCD
# 1602 i2C Afficheur LCD 1602 avec I2C s’agit d’une interface I2C,un
# module d’affichage LCD..
# 50,00DH
# Hors taxe : 50,00DH
# Ajouter au panier
# Plaque d'essai 400 Points
# Platine d’essai est particulièrement utile pour les développeurs électroniques et les étudiants en é..
# 19,00DH
# Hors taxe : 19,00DH
# Ajouter au panier
# CNC Shield V4 POUR NANO
# DescriptionShield CNC  et imprimant 3D, v4 pour l’Arduino NanoDescription :Ce module qui se bas..
# 75,00DH
# Hors taxe : 75,00DH
# Ajouter au panier
# Adaptateur Alimentation 12v
# Alimentation Chargeur 12V–2A Cette alimentation électrique est conçue pour alimenter les appare..
# 50,00DH
# Hors taxe : 50,00DH
# Ajouter au panier
# Arduino Leonardo R3 avec logo
# MicrocontrôleurATMega32u4Dimensions70 mm x 53 mm x 15 mmTension de fonctionnement5vtension d'aliment..
# 160,00DH
# Hors taxe : 160,00DH
# Ajouter au panier
# LED 5mm TRANSPARENT Rouge
# DescriptionEnsemble de 10 LEDSDiode LED rouge de très haute qualité avec une longueur d'onde de 620-..
# 1,00DH
# Hors taxe : 1,00DH
# Ajouter au panier
# Carte de commande de moteur L298N rouge
# Un microcontrôleur fonctionnant normalement sous 5 V ou 3,3 V ne peut pas être utilisé directement p..
# 45,00DH
# Hors taxe : 45,00DH
# Ajouter au panier
# Filament ABS 3D 1,75 mm – 1 kg – Noir
# Filament ABS de couleur noire pour imprimantes 3D 1,75 mm, 1,0 kg...
# 270,00DH
# Hors taxe : 270,00DH
# Ajouter au panier
# ZY-201 830 Points Plaque d'essai
# Bornier : point de raccordement 630Bandes de distribution : point de raccordement 200Matériau : plas..
# 76,00DH
# Hors taxe : 76,00DH
# Ajouter au panier
# Électrode ECG
# Feuille d’électrode pour adulte, accessoires de machine à ECG, patch de plomb d’électrocardiographie..
# 15,00DH
# Hors taxe : 15,00DH
# Ajouter au panier
# Rack PCB 40mm
# ..
# 20,00DH
# Hors taxe : 20,00DH
# Ajouter au panier
# Carte de pilote TB6560 3A pour routeur CNC, contrôleur à axe unique, pilotes de moteur pas à pas
# Les moteurs pas à pas  sont utilisés dans des applications nécessitant un contrôle précis ..
# 130,00DH
# Hors taxe : 130,00DH
# Ajouter au panier
# T GPIO RASPBERRY
# Le kit d'extension GPIO permet d'étendre l'interface GPIO du Raspberry Pi B+. Il vous permet de conn..
# 50,00DH
# Hors taxe : 50,00DH
# Ajouter au panier
# ULN2003A Driver Moteur Pas à pas
# Le circuit intégré ULN2003 est l'un des circuits de commande de moteur les plus couramment utilisés...
# 23,00DH
# Hors taxe : 23,00DH
# Ajouter au panier
# IN34 Germanium Diode
# ·
# Courant d'appel direct
# max. (Ifsm) : 500mA
#
# ·&n..
# 2,00DH
# Hors taxe : 2,00DH
# Ajouter au panier
# Écran d'affichage OLED 4pin 128x64 couleur bleue de 1,3 pouces
# Module OLED 1,3 "Module d'affichage 1,3 pouces Blanc 128X64 SPI / IIC I2C Communiquer la couleur Mod..
# 120,00DH
# Hors taxe : 120,00DH
# Ajouter au panier
# PAM8403 MINI 5V
# Les amplificateurs audio sont essentiels à tout système musical. Ils permettent de diffuser le son p..
# 25,00DH
# Hors taxe : 25,00DH
# Ajouter au panier
# QUARTZ
# ..
# 4,00DH
# Hors taxe : 4,00DH
# Ajouter au panier
# Module SD Card
# Alimentation:4.5V – 5.5V, 3.3VTrous: 4 x M2Connection PINS: GND, VCC, MISO, MOSI, SCK, CSSTaille:45 ..
# 20,00DH
# Hors taxe : 20,00DH
# Ajouter au panier
# Connecteur male DB9 à 9 broches YS-MH907A
# ..
# 45,00DH
# Hors taxe : 45,00DH
# Ajouter au panier
# Compteur ESR Fasizi LCR-T4
# Ajouter une fonction de détection de tension de démarrageDétection automatique des transistors NPN e..
# 170,00DH
# Hors taxe : 170,00DH
# Ajouter au panier
# Gaine 127 pcs
# - 30 gaines thermo-rétractables Ø 2,0 mm, longueur 40 mm- 25 gaines thermo-rétractables Ø 2,5 mm, lo..
# 70,00DH
# Hors taxe : 70,00DH
# Ajouter au panier
# Gaine 560 pcs
# Description
#
# Kit de Gaine 560 piéces
# Un Kit de gaines thermorétractable de 12 tailles et..
# 130,00DH
# Hors taxe : 130,00DH
# Ajouter au panier
# Jack femelle
# Nom du produit: Connecteur de montage de carte PCB de prise d'alimentation CC;Type : 5.5mm x 2.1mm S..
# 5,00DH
# Hors taxe : 5,00DH
# Ajouter au panier
# module clavier 4*4 V1.00
# Fonctionnalité:1. 4X4 ARRAY 16 TOUCHES: Le module de commutation du clavier est de conception 4x4 ar..
# 50,00DH
# Hors taxe : 50,00DH
# Ajouter au panier
# Kit d'invention MaKey MaKey
# De la marqueMAKEY MAKEYSi vous pouvez l'imaginer, vous pouvez le réaliser !Page précédenteDU PL..
# 390,00DH
# Hors taxe : 390,00DH
# Ajouter au panier
# Boule omnidirectionnelle en acier W420
# Description:Matériau : acier + plastiqueDirection : roulettes universellesSpécifications : 50 * 25 *..
# 13,00DH
# Hors taxe : 13,00DH
# Ajouter au panier
# XD-58C MODULE CAPTEUR DE RYTHME CARDIAQUE
# CaractéristiqueDescriptionTechnologiePhotopléthysmographie (PPG)Longueur d’onde de la LED940 nmType ..
# 70,00DH
# Hors taxe : 70,00DH
# Ajouter au panier
# Cable  multimètre 20A
# Cette paire de fils de test peut être utilisée avec la plupart des multimètres et constitue une sond..
# 30,00DH
# Hors taxe : 30,00DH
# Ajouter au panier
# V2.0 CAPTEUR SHIELD MEGA
# Module
# LM2596 avec affichage digital 2A
#
# Module abaisseur de tension
# DC/DC à base de régulateur ..
# 65,00DH
# Hors taxe : 65,00DH
# Ajouter au panier
# BMP 280 5V MODULE CAPTEUR DE PRESSION, TEMPÉRATURE, HUMIDITÉ
# MODULE CAPTEUR DE PRESSION, TEMPÉRATURE, HUMIDITÉ HAUTE PRÉCISION BME280 5VGY-BME280 BME280 est un c..
# 60,00DH
# Hors taxe : 60,00DH
# Ajouter au panier
# NEO-M8N-0-10
# L'antenne en céramique fournit un signal très fortAvec voyant LEDLe débit en bauds par défaut est de..
# 350,00DH
# Hors taxe : 350,00DH
# Ajouter au panier
# Raspberry PI 3B+
# Raspberry Pi 3 modèle B+ 2018
# Le Raspberry Pi 3 Model B + est le dernier produit de la gam..
# 850,00DH
# Hors taxe : 850,00DH
# Ajouter au panier
# Batterie Rechargeable 18650 2600mAH 3.7V
# Il s'agit d'une batterie 18650 3C originale de 2600 mAh de Hongli. Elle peut être cha..
# 19,00DH
# Hors taxe : 19,00DH
# Ajouter au panier
# Écran OLED Interface I2C de 0,96 pouces / SSD1306 bleu à 4 broches
# Les écrans OLED sont populaires pour leur faible consommation de courant et leurs angles de vision l..
# 100,00DH
# Hors taxe : 100,00DH
# Ajouter au panier
# Filament ABS 3D 1,75 mm – 1 kg – Bleu
# Filament ABS de couleur bleue pour imprimantes 3D 1,75 mm, 1,0 kg...
# 270,00DH
# Hors taxe : 270,00DH
# Ajouter au panier
# Roulement à billes 608ZZ (8 x 22 x 7 mm)
# Spécifications:
# Type: Roulement à billes à rainure profonde
# Lubrification : Graisse
# Matériau: Aci..
# 9,00DH
# Hors taxe : 9,00DH
# Ajouter au panier
# LED 10mm TRANSPARENTE Blanche
# Diode LED blanche de très haute qualité avec une température de couleur de 6000-9000K. La puissance ..
# 2,00DH
# Hors taxe : 2,00DH
# Ajouter au panier
# Informations
# Qui sommes nous
# Information sur la livraison
# Politique de confidentialité
# Conditions de vente
# Service client
# Nous contacter
# Retour de marchandise
# Plan du site
# Extras
# Fabricants
# Chèques-cadeaux
# Affiliations
# Promotions
# Mon compte
# Mon compte
# Historique de commandes
# Liste de souhaits
# Lettre d’information
# Développé Par
# ZOULO
# - ATMOSTECH © 2025
#
#
#
# about page
# Webpage Title:
# a_propos_de_nous
# Webpage Contents:
# +212674744471 / +212664166235
# Compte
# Inscription
# Connexion
# Liste de souhaits (0)
# Panier
# Commander
# 0 article(s) - 0,00DH
# Votre panier est vide !
# Catégories
# Cartes de développement
# Arduino
# Attiny
# ESP
# FPGA
# Raspberry
# STM
# Show All Cartes de développement
# Kit Atmostech
# Kit Capteur
# Kit De développement
# Kit Raspberry
# Kit Robot
# Show All Kit Atmostech
# Modules , capteurs , Shields
# CNC et Impression-3D
# Composants / Circuits intégrés
# Robotique , Outils
# Matériel de prototypage
# Matériel de soudage
# Moteur , Drivers
# Robotique
# Show All Robotique , Outils
# Connecteurs ,  Adaptateurs
# OPto-Electronique
# Afficheurs
# LED
# Show All OPto-Electronique
# Outillage , Accessoires
# Audio , Sonorisation
# Bouttons , Commutateurs
# Câbles
# Show All Outillage , Accessoires
# Appareils de mesure
# Qui sommes nous
# Qui sommes nous
# L’entreprise ATMOSTECH Engineering and Solutions a été fondée en 2019, dynamique, née d'une véritable passion pour la conception et la réalisation des bancs d’essai. Notre savoir-faire et nos compétences reposent sur un bureau d'études, nos compétences terrain et des personnels expérimentés et motivés. Quelque soit votre projet, l’entreprise ATMOSTECH Engineering and Solutions vous accompagne, identifie l'ensemble de vos besoins et vous propose une solution répondant à votre attente et offre un accompagnement judicieux.
# Notre philosophie
# :
# "Réaliser des prestations de qualité dans une recherche constante de la satisfaction du client"
# Nos valeurs :
# "Savoir-faire et Qualité, Engagement, Disponibilité, Responsabilité, Confiance et Proximité"
# Nos domaines d'activités :
# Distribution, vente, installation, et réalisation de matériel pour l’industrie, l'enseignement et la formation.
# Ingénierie en :
# Automatisme industriel et Système informatique industriel.
# Maintenance industrielle: électrique, mécanique, hydraulique, pneumatique et électronique.
# Importation de tout type de matériel didactique et industriel.
# Divers travaux dans le domaine d'ingénierie d'automatisme industriel, agriculture, apiculture.
# Informations
# Qui sommes nous
# Information sur la livraison
# Politique de confidentialité
# Conditions de vente
# Service client
# Nous contacter
# Retour de marchandise
# Plan du site
# Extras
# Fabricants
# Chèques-cadeaux
# Affiliations
# Promotions
# Mon compte
# Mon compte
# Historique de commandes
# Liste de souhaits
# Lettre d’information
# Développé Par
# ZOULO
# - ATMOSTECH © 2025

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short report about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous report - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey report about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_report_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short report of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:50_000] # Increased limit for Gemini (has larger context window)
    return user_prompt

# %%
get_report_user_prompt('atmostech', 'https://atmostech.ma/')
# Out:
# Found links: {'links': [{'type': 'contact page', 'url': 'https://atmostech.ma/contact'}, {'type': 'homepage', 'url': 'https://atmostech.ma/'}, {'type': 'about page', 'url': 'https://atmostech.ma/%C3%A0-propos-de-nous'}]}
# 'You are looking at a company called: atmostech\nHere are the contents of its landing page and other relevant pages; use this information to build a short report of the company in markdown.\nLanding page:\nWebpage Title:\nArduino Raspberry-pi & Composants électroniques | Maroc | Atmostech\nWebpage Contents:\n+212674744471 / +212664166235\nCompte\nInscription\nConnexion\nListe de souhaits (0)\nPanier\nCommander\n0 article(s) - 0,00DH\nVotre panier est vide !\nCatégories\nCartes de développement\nArduino\nAttiny\nESP\nFPGA\nRaspberry\nSTM\nShow All Cartes de développement\nKit Atmostech\nKit Capteur\nKit De développement\nKit Raspberry\nKit Robot\nShow All Kit Atmostech\nModules , capteurs , Shields\nCNC et Impression-3D\nComposants / Circuits intégrés\nRobotique , Outils\nMatériel de prototypage\nMatériel de soudage\nMoteur , Drivers\nRobotique\nShow All Robotique , Outils\nConnecteurs ,  Adaptateurs\nOPto-Electronique\nAfficheurs\nLED\nShow All OPto-Electronique\nOutillage , Accessoires\nAudio , Sonorisation\nBouttons , Commutateurs\nCâbles\nShow All Outillage , Accessoires\nAppareils de mesure\nBatteries , Accessoires\nBoitier ABS et Support\nCartes de développement\nConvertisseur\nKit Atmostech\nMicrocontroleur , Mémoire\nModules , capteurs , Shields\nProgrammateurs\nRésistance\nCNC et Impression-3D\nComposants / Circuits intégrés\nRobotique , Outils\nCapteurs\nConnecteurs ,  Adaptateurs\nOPto-Electronique\nOutillage , Accessoires\nAppareils de mesure\nMeilleures ventes\nLED VERT 5mm\nUne LED verte standard de 5 mm, utilisable à des fins d\'indication ou de visualisation. Elle peut êt..\n1,00DH\nHors taxe : 1,00DH\nAjouter au panier\nRÉSISTANCE 3 KOHM 1/4W +/- 1%\xa0Maroc\n..\n1,00DH\nHors taxe : 1,00DH\nAjouter au panier\nRÉSISTANCE 1 KOHM 1/4W +/- 1%\xa0Maroc\n..\n1,00DH\nHors taxe : 1,00DH\nAjouter au panier\nLED VERT 10mm\nCaractéristiques:460-470nmtension: 2.9-3.5VDCcourant: 20mAAngle de vue: 40-60 degree800-1000 MCD out..\n2,00DH\nHors taxe : 2,00DH\nAjouter au panier\nLED Rouge 10mm\nLentille: diamètre 10 mm / rondTension directe: 3V-3.2VCourant: 20mACouleur d’émission: rouge (455-4..\n2,00DH\nHors taxe : 2,00DH\nAjouter au panier\nLED JAUNE 5mm\nLes LED, ces petites puces clignotantes, sont indispensables pour l\'indication de l\'alimentation, l\'..\n1,00DH\nHors taxe : 1,00DH\nAjouter au panier\nRÉSISTANCE 220 OHM 1/4W +/- 1%\xa0Maroc\n..\n1,00DH\nHors taxe : 1,00DH\nAjouter au panier\nBouton clock kfc-12*12-7.5H\nMatériaux du corpsPlastiqueLongueur x Hauteur x Largeur12 mm x 12 mm x 7.5 mmNombre de terminaux4Ave..\n2,00DH\nHors taxe : 2,00DH\nAjouter au panier\nLED ROUGE 5mm\nUne LED rouge\xa0standard\xa0 de 5 mm\xa0\xa0, utilisable à des fins d\'indication ou de visu..\n1,00DH\nHors taxe : 1,00DH\nAjouter au panier\nJST 3 broches femelle\nConnecteurs femelles à broches 2,54 mmEnsemble de connecteurs JST couramment utilisés en robotique e..\n5,00DH\nHors taxe : 5,00DH\nAjouter au panier\nRÉSISTANCE 200 OHM 1/4W +/- 1%\xa0Maroc\n..\n1,00DH\nHors taxe : 1,00DH\nAjouter au panier\nARDUINO UNO R3   + avec câble\nDescriptionArduino Uno R3Arduino Uno est basée sur le microcontrôleur ATmega328P d’Atmel. Ce microco..\n120,00DH\nHors taxe : 120,00DH\nAjouter au panier\nEn vedette\nARDUINO NANO  + avec câble\nArduino Nano :Arduino Nano maroc est une carte de développement open-source basée sur un microcontrô..\n75,00DH\nHors taxe : 75,00DH\nAjouter au panier\nArduino Méga 2560 R3 sans logo + Câble USB\nArduino Méga 2560 (CH340) + Câble USBLa carte Arduino Méga est dotée d’un microcontrôleur ATMega2560..\n199,00DH\nHors taxe : 199,00DH\nAjouter au panier\nRaspberry pi 4 model B 2gb ram\n2 Go de mémoire SDRAM LPDDR4-3200 bProcesseur Broadcom\r\nBCM2711, SoC quadricœur Cortex-A72 (ARM v8) ..\n950,00DH\nHors taxe : 950,00DH\nAjouter au panier\nLCD 1602 i2C Afficheur\nLCD\r\n1602 i2C\xa0Afficheur LCD 1602 avec I2C s’agit d’une interface I2C,un\r\nmodule d’affichage LCD..\n50,00DH\nHors taxe : 50,00DH\nAjouter au panier\nPlaque d\ ...

# %%
def create_report(company_name, url):
    # Combine system prompt and user prompt for Gemini
    full_prompt = system_prompt + "\n\n" + get_report_user_prompt(company_name, url)
    
    response = model.generate_content(full_prompt)
    result = response.text
    display(Markdown(result))

# %%
create_report('atmostech','https://atmostech.ma/')
# Out:
# Found links: {'links': [{'type': 'contact page', 'url': 'https://atmostech.ma/contact'}, {'type': 'homepage', 'url': 'https://atmostech.ma/'}, {'type': 'about page', 'url': 'https://atmostech.ma/%C3%A0-propos-de-nous'}]}
# # Atmostech: Company Report
#
# Atmostech is a Moroccan company founded in 2019 that specializes in the distribution, sale, installation, and creation of equipment for industry, education, and training. They also offer engineering services in industrial automation and industrial computer systems, industrial maintenance (electrical, mechanical, hydraulic, pneumatic, and electronic), and import didactic and industrial equipment. They are located in Casablanca.
#
# **What Atmostech Offers:**
#
# *   **Products:** A wide range of electronic components, development boards (Arduino, Raspberry Pi, etc.), modules, sensors, CNC and 3D printing supplies, robotics tools, prototyping materials, and more.
# *   **Services:**
#     *   Engineering in industrial automation and industrial computer systems.
#     *   Industrial maintenance (electrical, mechanical, hydraulic, pneumatic, and electronic).
#     *   Import of didactic and industrial equipment.
#
# **Customers:**
#
# Atmostech serves a diverse customer base, including:
#
# *   Individuals (hobbyists, students)
# *   Educational institutions
# *   Industrial clients
#
# **Company Values & Philosophy:**
#
# Atmostech is committed to:
#
# *   Delivering high-quality services.
# *   Ensuring customer satisfaction.
# *   Maintaining values of:
#     *   Expertise and Quality
#     *   Commitment
#     *   Availability
#     *   Responsibility
#     *   Trust
#     *   Proximity
#
# **Contact Information:**
#
# *   **Phone:** +212674744471 / +212664166235
# *   **Address:** N° 5, Rue Hassan Elbasri -ex César Franck ,quartier: Belvédère - Casablanca
# *   **Opening Hours:** 8:00 AM - 6:00 PM
#
# **Note:** No information about company culture or job openings was found in the provided documents.

# %%
def stream_report(company_name, url):
    # Combine system prompt and user prompt for Gemini
    full_prompt = system_prompt + "\n\n" + get_report_user_prompt(company_name, url)
    
    # Generate streaming response
    response = model.generate_content(full_prompt, stream=True)
    
    full_response = ""
    display_handle = display(Markdown(""), display_id=True)
    
    for chunk in response:
        if chunk.text:
            full_response += chunk.text
            # Clean up markdown formatting
            cleaned_response = full_response.replace("```","").replace("markdown", "")
            update_display(Markdown(cleaned_response), display_id=display_handle.display_id)

# %%
stream_report('atmostech','https://atmostech.ma/')
# Out:
# Found links: {'links': [{'type': 'contact page', 'url': 'https://atmostech.ma/contact'}, {'type': 'homepage', 'url': 'https://atmostech.ma/'}, {'type': 'about page', 'url': 'https://atmostech.ma/%C3%A0-propos-de-nous'}, {'type': 'contact page', 'url': 'https://atmostech.ma/contact'}]}
# # Atmostech: A Summary for Prospective Customers, Investors, and Recruits
#
# Atmostech Engineering and Solutions, founded in 2019 and based in Casablanca, Morocco, is a dynamic company born from a passion for design and building test benches. They offer a range of products and services within the industrial automation, electronics, and robotics sectors.
#
# ## What Atmostech Offers:
#
# *   **Products:** Specializing in the sale and distribution of electronic components, development boards (Arduino, Raspberry Pi, ESP), modules, sensors, CNC and 3D printing equipment, robotics tools, and prototyping materials. They also offer various kits, including Atmostech kits, sensor kits, and robot kits.
# *   **Engineering Services:** Providing expertise in industrial automation, industrial IT systems, and general engineering work in areas like agriculture and apiculture.
# *   **Maintenance Services:** Offering industrial maintenance services spanning electrical, mechanical, hydraulic, pneumatic, and electronic systems.
#
# ## Who are Atmostech's Customers?
#
# Atmostech serves a diverse customer base, including:
#
# *   Individuals and hobbyists interested in electronics and DIY projects.
# *   Educational institutions looking for didactic and industrial equipment.
# *   Industries requiring automation solutions, maintenance, and specialized equipment.
#
# ## Atmostech's Company Culture and Values:
#
# Atmostech is committed to:
#
# *   Delivering high-quality services with a focus on customer satisfaction.
# *   Providing expertise and quality.
# *   Maintaining engagement, availability, responsibility, trust, and proximity with clients.
#
# ## Contact Information
#
# *   **Address:** N° 5, Rue Hassan Elbasri -ex César Franck ,quartier: Belvédère - Casablanca
# *   **Phone:** +212674744471 / +212664166235, +2120674744471
# *   **Hours:** 8:00 - 18:00
#
# **In Summary:**
#
# Atmostech is a versatile company with a strong focus on quality and customer satisfaction. They serve as a supplier of electronic components and a provider of engineering and maintenance services.
